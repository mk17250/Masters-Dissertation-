# %% [markdown]
# # Masters Dissertation - Advent Insurance Management - Facilitiating Same-Day Settlement and Fraud Detection with ML

# %% [markdown]
# ## Import required libaries

# %%
import pandas as pd 
import numpy as np 
import datetime
from matplotlib import pyplot as plt
import plotly.figure_factory as ff
import seaborn as sns
from imblearn.over_sampling import SMOTE

import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)

from imblearn.over_sampling import SMOTE
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn import svm, preprocessing, metrics
from sklearn.model_selection import GridSearchCV, cross_val_score, train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import make_scorer, confusion_matrix, accuracy_score, precision_recall_fscore_support, roc_auc_score 
import winsound

# %% [markdown]
#  ## Define function to import data and merge datasets

# %%
# Create function to import data and drop duplicated data from each df 
# Import data (you manually dropped the first two lines from the excel file in excel in order to capture the 
# header information)
# Note primary keys: Catastrophe Name (dive_assure), ID (Policy)
def import_data():
    """Function to import both the Policy and DiveAssure datasets and drop duplicates, with both file paths already 
    inside function - NOTE thiswill not work on another computer or file location, paths must updated"""
    dive_assure = pd.read_excel(r'C:\Users\Home\OneDrive\Advent\LloydsBordereauV5-J.xlsx')
    policy = pd.read_csv(r'C:\Users\Home\OneDrive\Advent\PolicyInfoLloydsBordereau.csv')
    # Drop duplicate data from dfs
    dive_assure = dive_assure.drop_duplicates(subset='Catastrophe Name')
    policy = policy.drop_duplicates(subset='ID')
    # Change colname of dive_assure from Catastrophe Name to ID for merge 
    dive_assure = dive_assure.rename(columns={'Catastrophe Name': 'ID'})
    # Change ID type to string and drop decimal 
    policy['ID'] = policy['ID'].astype(str).apply(lambda x: x.replace('.0',''))
    # Change ID in dive to str 
    dive_assure['ID'] = dive_assure['ID'].astype(str)
    # Merge dfs
    df = pd.merge(policy, dive_assure, on='ID', sort=False, how='left')
    return df

# %%
# A function to get names of features  
def col_names(df):
    """pass both df's and will return feature names for each df"""
    df_colnames = df.columns 
    return df_colnames

# %% [markdown]
# # Begin Cleaning the Data

# %%
# Change cell settings to display all rows 
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
# A function to identiy features wuth values <= 1 and drop them from the df 
def drop_low_info_cols(df):
    """Takes features with no or little unique values and drops them from df"""
    # Create dict object of unique values for df 
    uniques = dict(df.nunique())

    # Which features have <= 1 value 
    features_to_delete = [] # store values 
    for k,v in uniques.items():
        if v <= 1:
            features_to_delete.append(k)
    #drop columns from features_to_delete list
    for i in features_to_delete:
        df = df.drop([i], axis = 1)
    return df

# %%
# Function to drop features with little information gain such as name, or features that are added during the claims 
# handling process and would therefore be unavilable at the point of running the script
def drop_features(df):
    """Pass df and will drop relevant features"""
    df = df.drop(['Certificate Reference',
           'Claim Reference / Number', 'Insured Full Name or Company Name',
           'Loss Description', 'Claim Status', 'Refer to Underwriters', 'Loss Description',
           'Paid this month - Indemnity', 'Paid this month - Fees',
           'Previously Paid - Indemnity', 'Previously Paid - Fees',
           'Reserve - Indemnity', 'Reserve - Fees',
           'Change this month - Indemnity', 'Change this month - Fees',
           'Total Incurred - Indemnity', 'Total Incurred - Fees', 'Date Closed',
           'Paid this month - Expenses', 'Claimant Name',
           'Paid this month - Adjusters Fees', 'Paid this month - TPA Fees',
           'Previously Paid - Expenses', 'Previously Paid - Adjusters Fees',
           'Previously Paid - TPA Fees',
           'Reserve - TPA Fees', 'Total Incurred',
           'Date Claims Paid (Final)', 'Date Fees Paid (Final)', 'Date Reopened',
           'Claim First Notification Acknowledgement Date',
           'Date First Reserve Established', 'Peer review date','Rate of Exchange', 
           'Location of loss State, Province, Territory, Canton', 'Transaction ID', 'Created By',
           'Registration Type', 'Address 1', 'Email', 'First Name', 'Last Name'], axis=1)
    # drop rows where label = NaN
    df = df.dropna(subset=['Denial', 'Creation Date'])
    # Change NaNs and NaTs to 0 of remaining features 
    df = df.fillna(0)
    return df

# %%
# # Reset cell display settings 
# pd.reset_option("display.max_rows")
# # pd.reset_option("display.max_columns")
# # Display df 
# df

# %%
# # Assess unique values and feature 
# # Create dict object of unique values for df 
# uniques_1 = dict(df.nunique())

# # Show number of unique values
# for k,v in uniques_1.items():
#         print(k, v)

# %% [markdown]
# # EDA and visualisation

# %%
# Import data for EDA 
df_eda = import_data()

# %%
df_city = pd.DataFrame(df_eda['City'])

# %%
# Function to drop additional cols which make no sense to visualise ie Dates etc 
def drop_for_vis(df):
    """Pass df and drop additional features for visualisation"""
    df = df.drop(['Creation Date', 'Risk Inception Date', 'Risk Expiry Date', 'Date Claim First Advised/Date Claim Made', 
                 'Date Claim Opened', 'From', 'To', 'Date of Loss (From)', 'Zip', 'ID', 'City'], axis=1)
    # Change from object to datetime
    df['Date of Birth'] = df['Date of Birth'].apply(pd.to_datetime)
    # Change structure og datetime object
    df['Date of Birth'] = (pd.to_datetime('now') - df['Date of Birth']).astype('<m8[Y]')
    # Rename column
    df.rename(columns={'Date of Birth': 'Years of Age'}, index={'Date of Birth': 'Years of Age'}, inplace=True)
#     df['City'] = df['City'].astype('str')
#     df['City'] = df['City'].str.replace(r"-"," ")
    cols = ['Cause of Loss Code', 'Lloyd\'s Cat Code', 'Insured State, Province, Territory, Canton etc.']
    df[cols] = df[cols].replace({0:'Unknown', '0':'Unknown', '07-Jul': 'A'})
    df['Is Secondary'] = df['Is Secondary'].astype(str)
    df['Main Member Non-Diving'] = df['Main Member Non-Diving'].astype(str)
    return df

# %%
# Drop unwanted features from df 
df_eda = drop_low_info_cols(df_eda).pipe(drop_features).pipe(drop_for_vis)

# %%
# Show histograms of numerical variables
df_eda.hist(bins=15, figsize=(18,8), layout=(4,6))
# Out:
# array([[<AxesSubplot:title={'center':'Years of Age'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# Display all categorical features using bar plots 
import matplotlib.pyplot as plt
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

categorical=[]
for column in df_eda:
    if is_string_dtype(df_eda[column]):
        categorical.append(column)


fig, ax = plt.subplots(6, 2, figsize=(18, 32))
for variable, subplot in zip(categorical, ax.flatten()):
    sns.countplot(df_eda[variable], ax=subplot, palette='bright')
    for label in subplot.get_xticklabels():
        label.set_rotation(90)
fig.tight_layout()

# %%
# Change cell settings to display all rows 
# pd.set_option("display.max_rows", None)
# pd.set_option("display.max_columns", None)
pd.reset_option("display.max_rows")

# %%
# Visualise city feature with droped cities that only appear once
counts = dict(df_city.value_counts())
significants = []
insignificants = []

# Which features have > 1 value 
features_to_delete = [] # store values 
for k,v in counts.items():
    if v > 1:
        significants.append(k)
    else:
        insignificants.append(k)
        
significants = pd.DataFrame(significants)[0].str.replace("(", "").str.replace("'", "").str.replace(",", "").str.replace(")", "")
significants = list(significants)
df_a = df_city[df_city['City'].isin(significants)]

a = sns.countplot(df_a['City'], palette='bright')
a.set_xticklabels(a.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.show()

# %%
# Create histograms of numeric features with cases of fraud/no fraud highlighted 

# numeric col names 
column_name='Years of Age'
# encode = preprocessing.LabelEncoder()
# df_eda[['Denial']] = df_eda[['Denial']].apply(encode.fit_transform)


# create df using numeric cols 
df_hist = df_eda.loc[:, [c for c in df_eda if c in column_name]]
# add target variable to df 
df_hist['Denial'] = df_eda['Denial']
# drop target and convert to array
data_array = np.array(df_hist)[:,0:-1]

# create df's with all rows of Denial/No Denial, then convert to arrays 
fig, ax = plt.subplots(figsize=(4,4))
no_denial1 = df_hist.loc[df_hist['Denial'] == 'N']
no_denial = np.array(no_denial1)[:,0:-1]
denial1 = df_hist.loc[df_hist['Denial'] == 'Y']
denial = np.array(denial1)[:,0:-1]


ax.hist(no_denial, bins=50, color='cornflowerblue', alpha=.5)
ax.hist(denial, bins=50, color='red', alpha=.5)
ax.set_title(column_name)
ax.set_yticks(())
ax.set_xlabel("Scale")
ax.set_ylabel("frequency")
ax.legend(["no_denial", "denial"], loc="best")
fig.tight_layout()

# %%
# Create bar plots using seaborn catplot highlighting Denial/No Denial differences

df_denial = df_eda[df_eda['Denial'] == 'Y']
df_no_denial = df_eda[df_eda['Denial'] == 'N']

for variable in categorical:
    plot = sns.catplot(x=variable, col="Denial", data=df_eda, kind='count',height=6, aspect=1.3, palette = 'bright')
    plot.set_xticklabels(rotation=90)
fig.tight_layout()

# %%
# Examine target varible 
plt.figure(figsize=(6,6))
sns.countplot(x = 'Denial', data = df_eda, palette = 'bright')
# Out:
# <AxesSubplot:xlabel='Denial', ylabel='count'>

# %%
len(df_eda)
# Out:
# 343

# %% [markdown]
# # Preprocessing

# %%
# Function to clean certain features of the data and to label encode relevant features
def encode(df):
    """Takes df, cleans and applies label encoding """
    # Convert DOB from string to date_time object 
    cols = ['Date of Birth', 'Creation Date', 'From', 'To']
    df[cols] = df[cols].apply(pd.to_datetime)
    # Convert DOB from yyyy-mm-dd to years 
    df['Date of Birth'] = (pd.to_datetime('now') - df['Date of Birth']).astype('<m8[Y]')
    # Drop time stamp from Creation date 
    df['Creation Date'] = pd.to_datetime(df['Creation Date']).dt.date
    df['Creation Date'] = pd.to_datetime(df['Creation Date'])
    
    # Change type of city feature 
    df['City'] = df['City'].astype('str')

    #Change int and random value == random str
    cols = ['City', 'Cause of Loss Code', 'Lloyd\'s Cat Code', 'Insured State, Province, Territory, Canton etc.']
    df[cols] = df[cols].replace({0:'A', '0':'A', '07-Jul': 'A'})


    encode = preprocessing.LabelEncoder()
    df[['Program Name', 'Is Secondary', 'Main Member Non-Diving', 'State/Province', 'Country',
       'Original Currency', 'Location of loss Country', 'Insured Country', 'Denial', 
       'City', 'Cause of Loss Code', 'Lloyd\'s Cat Code',
       'Insured State, Province, Territory, Canton etc.']] = df[['Program Name', 
                                                                 'Is Secondary', 
                                                                 'Main Member Non-Diving', 
                                                                 'State/Province',
                                                                 'Country',
                                                                 'Original Currency',
                                                                 'Location of loss Country',               
                                                                 'Insured Country',
                                                                 'Denial',
                                                                 'City', 
                                                                 'Cause of Loss Code', 
                                                                 'Lloyd\'s Cat Code',
                                                                 'Insured State, Province, Territory, Canton etc.'
                                                                 ]].apply(encode.fit_transform)
    return df

# %%
# Check all NaNs have been removed/converted 
# df.isnull().sum()

# %%
# View data types
# df.dtypes

# %% [markdown]
# # Use dates to extract meaning about claim

# %%
# Create function to use policy date infromation to return numbers of days or if claim is made within covered period
def use_dates(df):
    """Pass df and will return df with dates used to create count days, will drop orginal dates"""
    # Total days from policy taken out (creation date) to DOL (date of loss) 
    df['Total days from policy taken to DOL'] = (df['Date of Loss (From)']-df['Creation Date']).dt.days
    # Total number of days from DOL to (date claim first advised/date claim made) 
    df['Total days from DOL to claim made'] = (df['Date Claim First Advised/Date Claim Made']-df['Date of Loss (From)']).dt.days
    # Check DOL is within timeframe (From-To) 
    df['Is DOL in policy period'] = df['Date of Loss (From)'].between(df['From'],df['To']).astype(int)
    # Change 0's back to floating point numbers 
    df.ID = pd.to_numeric(df.ID, errors='coerce').fillna(0).astype(np.int64)
    df.Zip = pd.to_numeric(df.Zip, errors='coerce').fillna(0).astype(np.int64)
    df = df.drop(['Risk Inception Date','Risk Expiry Date', 'Date of Loss (From)', 
              'Creation Date', 'Date Claim First Advised/Date Claim Made', 'Date Claim Opened',
             'From', 'To', 'Date of Birth', 'ID', 'Zip'], axis=1)
    return df

# %%
# Total number of days from (date claim first advised/date claim made) to (date claim opened)
# df['Total days from first advised-claim made'] = (df['Date Claim Opened']-df['Date Claim First Advised/Date Claim Made']).dt.days

# %%
# Function to get_dummies 

# def function for get dummies few
def get_dummies_few(df):
    """Function to create dummy variable for cols, pass df """
    # Create cols list for get_dummies func
    cols = ['Program Name', 'Original Currency', 'Cause of Loss Code', 'Lloyd\'s Cat Code']
    df = pd.get_dummies(data=df, columns=cols)
    return df 

# def function for get dummies all
def get_dummies_all(df):
    """Function to create dummy variable for cols, pass df """
    # Create cols list for get_dummies func
    cols = ['Program Name', 'Is Secondary', 'Main Member Non-Diving',
       'State/Province', 'City', 'Country', 'Original Currency',
       'Insured State, Province, Territory, Canton etc.', 'Insured Country',
       'Location of loss Country', 'Cause of Loss Code',
       'Lloyd\'s Cat Code', 'Total days from policy taken to DOL',
       'Total days from DOL to claim made', 'Is DOL in policy period']
    df = pd.get_dummies(data=df, columns=cols)
    return df

# %% [markdown]
# # Run functions and return df

# %%
df = import_data().pipe(drop_low_info_cols).pipe(drop_features).pipe(encode).pipe(use_dates)

# %%
# Check all NaNs have been removed/converted 
df.isnull().sum()
# Out:
# Program Name                                       0
# Is Secondary                                       0
# Main Member Non-Diving                             0
# State/Province                                     0
# City                                               0
# Country                                            0
# Original Currency                                  0
# Insured State, Province, Territory, Canton etc.    0
# Insured Country                                    0
# Location of loss Country                           0
# Cause of Loss Code                                 0
# Denial                                             0
# Lloyd's Cat Code                                   0
# Total days from policy taken to DOL                0
# Total days from DOL to claim made                  0
# Is DOL in policy period                            0
# dtype: int64

# %%
# View data types
df.dtypes
# Out:
# Program Name                                       int32
# Is Secondary                                       int64
# Main Member Non-Diving                             int64
# State/Province                                     int32
# City                                               int32
# Country                                            int32
# Original Currency                                  int32
# Insured State, Province, Territory, Canton etc.    int32
# Insured Country                                    int32
# Location of loss Country                           int32
# Cause of Loss Code                                 int32
# Denial                                             int32
# Lloyd's Cat Code                                   int32
# Total days from policy taken to DOL                int64
# Total days from DOL to claim made                  int64
# Is DOL in policy period                            int32
# dtype: object

# %%
# grid.cv_results_

# %%
# Create heat map to visulaise correlation between features 
sns.set(rc = {'figure.figsize':(15,8)})
heat_map = sns.heatmap(df.corr())
heat_map
# Out:
# <AxesSubplot:>

# %%
# Correlation Matrix Heatmap
f, ax = plt.subplots(figsize=(10, 6))
corr = df.corr()
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
                 linewidths=.05)
plt.yticks(rotation=0) 
f.subplots_adjust(top=0.93)
t = f.suptitle('Features Correlation Heat Map', fontsize=14)

# %% [markdown]
# ### Define function to split x, y, x_train, x_test, y_train, y_test

# %%
# Function to create x and y, then x_test, y_test

def train_test(df):
    """Takes df and returns x, y, x_train, y_train, x_test, y_test"""
    
    # Split into x and y 
    x = df.loc[:, df.columns != 'Denial']
    y = pd.DataFrame(df['Denial'])

    # split the data into train and test set
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, shuffle=True)
    
    return x, y, x_train, x_test, y_train, y_test

# %%
# call function and set varaibles from df 
x, y, x_train, x_test, y_train, y_test = train_test(df)

# %% [markdown]
# ### SMOTE

# %%
#Over sample the minority class using SMOTE

sm = SMOTE(random_state=42)

x_sm, y_sm = sm.fit_resample(x_train, y_train)

print(f'''Shape of x before SMOTE: {x_train.shape}
Shape of x after SMOTE: {x_sm.shape}''')
# Out:
# Shape of x before SMOTE: (274, 15)
# Shape of x after SMOTE: (388, 15)

# %%
# Visualise target variable Churn 
y_smote = pd.DataFrame(y_sm, columns = ['Denial'])
# Target Varibale is now balanced
plt.figure(figsize=(6,6))
sns.countplot(x = 'Denial', data = y_smote, palette='bright')
# Out:
# <AxesSubplot:xlabel='Denial', ylabel='count'>

# %% [markdown]
# ### Define functions to define and apply ML models

# %% [markdown]
# ### DT

# %%
# Function to perform nested CV on DT model 
def DT_nested(x_train, y_train):
    """pass x_train, y_train and function will perfrom nested CV on DT model to indicate how model may generalise"""
    
    clf = DecisionTreeClassifier()
    param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : [2,4,6,8,10],
    'class_weight': [{0: 1, 1: 1}, {0: 1, 1: 5}, {0: 1, 1: 10}, {0: 1, 1: 25}, 'balanced'] 
    }
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring="f1")
    scores = cross_val_score(grid, x_train, y_train, cv=5, scoring="f1")
    print('Average cross_val score of DT: %.4f' % scores.mean())

# %%
# Function to perform gridsearch and return optimal parameters 
def DT_grid(x_train, x_test, y_train, y_test):
    """pass x_train, X_test, y_train, y_test and function will perfrom gridsearch CV and return scores and print best params"""
    
    clf = DecisionTreeClassifier()
    param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : [2,4,6,8,10],
    'class_weight': [{0: 1, 1: 1}, {0: 1, 1: 5}, {0: 1, 1: 10}, {0: 1, 1: 25}, 'balanced'] 
    }
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring='f1')
    grid.fit(x_train, y_train.values.ravel())
    
    # Mean cross-validated score of the best_estimator
    return print(" The best cross validation score for the DT model is: "  + np.str("%0.4f" % grid.best_score_) + 
                 "\n The best parameters for the DT model: " + np.str(grid.best_params_) + 
                 "\n Test score: {:.4f}".format(grid.score(x_test, y_test.values.ravel())))

# %%
# Function to provide evaulate optimal model on test data 
def DT_eval(x_train, x_test, y_train, y_test, criterion='entropy', max_depth=4, class_weight='balanced'):
    """Create confusion matrix. Pass best params manually from printed DT_grid function result"""
    clf=DecisionTreeClassifier(criterion=criterion, max_depth=max_depth, class_weight=class_weight)
    clf.fit(x_train, y_train.values.ravel())
    DT_preds = clf.predict(x_test)
    DT_acc = clf.score(x_test, y_test.values.ravel())
    DT_cm = confusion_matrix(y_test, DT_preds)
    DT_precision, DT_recall, DT_f1score, _ = precision_recall_fscore_support(y_test, DT_preds, average='binary')
    DT_auc = roc_auc_score(y_test, DT_preds)
    return DT_acc, DT_cm, DT_precision, DT_recall, DT_f1score, DT_auc, DT_preds

# %% [markdown]
# ### Random Forrest

# %%
# Function to perform nested CV on RF model 
def RF_nested(x_train, y_train):
    """pass x_train, y_train and function will perfrom nested CV on RF model to indicate how model may generalise"""
    
    clf = RandomForestClassifier()
    param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : [2,4,6,8,10],
    'class_weight': [{0: 1, 1: 1}, {0: 1, 1: 5}, {0: 1, 1: 10}, {0: 1, 1: 25}, 'balanced'] 
    }
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring="f1")
    scores = cross_val_score(grid, x_train, y_train, cv=5, scoring="f1")
    print('Average cross_val score of RF: %.4f' % scores.mean())

# %%
# Function to perform gridsearch with CV and return optimal parameters 
def RF_grid(x_train, x_test, y_train, y_test):
    """pass x_train, X_test, y_train, y_test and function will perfrom gridsearch CV and return scores and print best params"""
    
    clf = RandomForestClassifier()
    param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : [2,4,6,8,10],
    'class_weight': [{0: 1, 1: 1}, {0: 1, 1: 5}, {0: 1, 1: 10}, {0: 1, 1: 25}, 'balanced'] 
    }
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring="f1")
    grid.fit(x_train, y_train.values.ravel())
    
    # Mean cross-validated score of the best_estimator
    return print(" The best cross validation score for the RF model is: "  + np.str("%0.4f" % grid.best_score_) + 
                 "\n The best parameters for the RF model: " + np.str(grid.best_params_) + 
                 "\n Test score: {:.4f}".format(grid.score(x_test, y_test.values.ravel())))

# %%
# Function to evaulate optimised model on test data 
def RF_eval(x_train, x_test, y_train, y_test, criterion='gini', max_depth=6, class_weight={0: 1, 1: 5}):
    """Create confusion matrix. Pass best params manually from printed DT_grid function result"""
    clf=RandomForestClassifier(criterion=criterion, max_depth=max_depth, class_weight=class_weight)
    clf.fit(x_train, y_train.values.ravel())
    RF_preds = clf.predict(x_test)
    cm = confusion_matrix(y_test, RF_preds)
    RF_acc = clf.score(x_test, y_test.values.ravel())
    RF_cm = confusion_matrix(y_test, RF_preds)
    RF_precision, RF_recall, RF_f1score, _ = precision_recall_fscore_support(y_test, RF_preds, average='binary')
    RF_auc = roc_auc_score(y_test, RF_preds)
    return RF_acc, RF_cm, RF_precision, RF_recall, RF_f1score, RF_auc, RF_preds

# %% [markdown]
# ### SVM

# %%
# Function to perform nested CV with grid search on SVM to examine how the model will potentially generalise 
def SVM_nested(x_train, y_train):
    """Pass x,y and function performs nested CV with gridsearch with SVM"""
    scaler = StandardScaler()
    x_train = scaler.fit_transform(x_train)
    clf = svm.SVC() # define model
#     pipe = Pipeline([('scale', StandardScaler()), ('clf', clf)]) #create pipe 
    param_grid = {'C': [0.1,1,10,100],
#                   'scale' : [StandardScaler(), 'passthrough'],
                  'gamma': [1,0.1,0.01,0.001],
                  'class_weight': [{0:100,1:1}, {0:10,1:1}, {0:1,1:1}, {0:1,1:10}, {0:1,1:100}]}
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring='f1') 
    scores = cross_val_score(grid, x_train, y_train.values.ravel(), cv=10, scoring='f1') 
    # report performance
    return print('Average cross_val score of SVM: %.4f' % scores.mean())

# %%
# Function which performs gridsearch and returns scores and best params 
def SVM_grid(x_train, x_test, y_train, y_test):
    """Pass x_train, x_test, y_train, y_test"""
    scaler = StandardScaler()
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)
    clf = svm.SVC() # define model
    param_grid = {'C': [0.1,1,10,100,250],
                  'gamma': [1,0.1,0.01,0.001],
                  'class_weight': [{0:100,1:1}, {0:10,1:1}, {0:1,1:1}, {0:1,1:10}, {0:1,1:100}]}
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring='f1') 
    grid.fit(x_train, y_train.values.ravel()) # fit 
    
    # Mean cross-validated score of the best_estimator
    return print(" The best cross validation score for the SVM model is: "  + np.str("%0.4f" % grid.best_score_) + 
                 "\n The best parameters for the SVM model: " + np.str(grid.best_params_) + 
                 "\n Test score: {:.4f}".format(grid.score(x_test, y_test.values.ravel())))

# %%
# Function to evaluate cm of SVM on test data 
def SVM_eval(x_train, x_test, y_train, y_test, C = 0.1, class_weight= {0: 100, 1: 1}, gamma= 1):
    """pass x_train, x_test, y_train, y_test and best params manually from printed grid result"""
    scaler = StandardScaler()
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)
    clf = svm.SVC(C=C, gamma=gamma, class_weight = class_weight)
    clf.fit(x_train, y_train.values.ravel())
    SVM_preds = clf.predict(x_test)
    cm = confusion_matrix(y_test, SVM_preds)
    SVM_acc = clf.score(x_test, y_test)
    SVM_cm = confusion_matrix(y_test, SVM_preds)
    SVM_precision, SVM_recall, SVM_f1score, _ = precision_recall_fscore_support(y_test, SVM_preds, average='binary')
    SVM_auc = roc_auc_score(y_test, SVM_preds)
    return SVM_acc, SVM_cm, SVM_precision, SVM_recall, SVM_f1score, SVM_auc, SVM_preds

# %% [markdown]
# ### XGBoost

# %%
# Function to perform nested grid search on XGB
def XGB_nested(x_train, y_train):
    """Takes x_train, y_train and performs nested grid search and return best score, indicates how model will generalise 
    to unseen data"""

    # Nested CV to indicate how well model will generalise to unseen data 
    clf = XGBClassifier(validate_parameters=True, objective="binary:logistic", silent=True, verbosity=0)
#     param_grid = {
#     "max_depth": [3, 4, 5, 7],
#     "learning_rate": [0.1, 0.01, 0.05],
#     "gamma": [0, 0.25, 1],
#     "reg_lambda": [0, 1, 10],
#     "scale_pos_weight": [1, 3, 5],
#     "subsample": [0.8],
#     "colsample_bytree": [0.5],
#     }
    param_grid = {'learning_rate': [0.0001,0.001,0.01,0.1,0.5,1], 
                  'max_depth': [2,3,5,10,15,20],
                 'scale_pos_weight': [1, 10, 25, 50, 75, 99, 100]}
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring="recall") 
    scores = cross_val_score(grid, x_train, y_train.values.ravel(), cv=5, scoring="recall") 
    
    # report performance
    return print('Average cross_val score of XGBoost: %.4f' % scores.mean())

# %%
# Function for XGB evaluation 
def XGB_grid(x_train, x_test, y_train, y_test):
    """Takes x and y and performs grid search, returns CV score, best paras from grid search, score on test set,
    and confusion matrix"""
    
    clf = XGBClassifier(validate_parameters=True, objective="binary:logistic", silent=True, verbosity=0)
    
    # Hyper-tuner parameters and print results 
#     param_grid = {
#     "max_depth": [3, 4, 5, 7],
#     "learning_rate": [0.1, 0.01, 0.05],
#     "gamma": [0, 0.25, 1],
#     "reg_lambda": [0, 1, 10],
#     "scale_pos_weight": [1, 3, 5, 10],
#     "subsample": [0.8],
#     "colsample_bytree": [0.5],
#     }
    param_grid = {'learning_rate': [0.0001,0.001,0.01,0.1,0.5,1], 
                  'max_depth': [2,3,5,10,15,20],
                 'scale_pos_weight': [1, 10, 25, 50, 75, 99, 100]}
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring="recall")
    grid.fit(x_train, y_train.values.ravel()) # fit 
    
    # # Mean cross-validated score of the best_estimator
    return print(" The best cross validation score with parameter tuning for the XGB model is: "  + np.str("%0.4f" % grid.best_score_) + 
                 "\n The best parameters for the XGB model: " + np.str(grid.best_params_) + 
                 "\n Test score: {:.4f}".format(grid.score(x_test, y_test.values.ravel())))

# %%
# Function to evaluate SVM on test data 
def XGB_eval(x_train, x_test, y_train, y_test, learning_rate=1, max_depth=5, scale_pos_weight=5):
    """pass x_train, x_test, y_train, y_test and best params manually from printed grid result"""
    clf = XGBClassifier(validate_parameters=True, objective="binary:logistic", 
   
                        learning_rate=learning_rate, max_depth=max_depth, 
                        scale_pos_weight=scale_pos_weight)
    clf.fit(x_train, y_train.values.ravel())
    XGB_preds = clf.predict(x_test)
    cm = confusion_matrix(y_test, XGB_preds)
    XGB_acc = clf.score(x_test, y_test.values.ravel())
    XGB_cm = confusion_matrix(y_test, XGB_preds)
    XGB_precision, XGB_recall, XGB_f1score, _ = precision_recall_fscore_support(y_test, XGB_preds, average='binary')
    XGB_auc = roc_auc_score(y_test, XGB_preds)
    return XGB_acc, XGB_cm, XGB_precision, XGB_recall, XGB_f1score, XGB_auc, XGB_preds  

# colsample_bytree = 0.5, gamma = 0, learning_rate=0.001, max_depth=3, 
#              reg_lambda = 10, scale_pos_weight = 5, subsample = 0.8

# subsample=subsample, silent=True, verbosity=0, reg_lambda=reg_lambda, colsample_bytree = 0.5, gamma = 0,

# %% [markdown]
# # Run functions and apply ML models to data and evaluate performance

# %% [markdown]
# ### Data with just preprocessing

# %% [markdown]
# ### DT

# %%
df
# Out:
#      Program Name  Is Secondary  Main Member Non-Diving  State/Province  City  \
# 0               2             0                       0              17   226
# 2               7             0                       0              48    99
# 3               6             1                       0              67    45
# 4               6             1                       0              57   216
# 5               3             1                       0               5     4
# ..            ...           ...                     ...             ...   ...
# 394             2             0                       0              48    50
# 395             1             1                       0              72   151
# 396             6             1                       0              60   210
# 397             6             1                       0              67    20
# 398             2             1                       0              36   248
#
#      Country  Original Currency  \
# 0         17                  7
# 2         48                  7
# 3         67                  7
# 4         57                  7
# 5          5                  7
# ..       ...                ...
# 394       48                  7
# 395       72                  7
# 396       60                  7
# 397       67                  7
# 398       36                  7
#
#      Insured State, Province, Territory, Canton etc.  Insured Country  \
# 0                                                 15               46
# 2                                                  1               46
# 3                                                  1               23
# 4                                                  1               40
# 5                                                  1                2
# ..                                               ...              ...
# 394                                                1               46
# 395                                                1               46
# 396                                                1               28
# 397                                                1               42
# 398                                                1               46
#
#      Location of loss Country  Cause of Loss Code  Denial  Lloyd's Cat Code  \
# 0                          37                   1       1                 0
# 2                          37                   1       1                 0
# 3                          27                   2       0                 0
# 4                          47                   2       0                 0
# 5                          52                   3       0                 0
# ..                        ...                 ...     ...               ...
# 394                        52                   0       0                 0
# 395                        52                   0       0                 2
# 396                        30                   0       0                 0
# 397                        49                   0       0                 0
# 398                        52                   0       0                 0
#
#      Total days from policy taken to DOL  Total days from DOL to claim made  \
# 0                                      4                                  6
# 2                                      1                                 14
# 3                                     13                                  6
# 4                                      8                                 28
# 5                                      2                                 35
# ..                                   ...                                ...
# 394                                   47                                 40
# 395                                   32                                 21
# 396                                   14                                 22
# 397                                  130                                  8
# 398                                  492                                 72
#
#      Is DOL in policy period
# 0                          1
# 2                          1
# 3                          1
# 4                          1
# 5                          1
# ..                       ...
# 394                        1
# 395                        1
# 396                        1
# 397                        1
# 398                        1
#
# [343 rows x 16 columns]

# %%
df.nunique()
# Out:
# Program Name                                        11
# Is Secondary                                         2
# Main Member Non-Diving                               2
# State/Province                                      76
# City                                               273
# Country                                             76
# Original Currency                                    8
# Insured State, Province, Territory, Canton etc.     62
# Insured Country                                     48
# Location of loss Country                            55
# Cause of Loss Code                                   6
# Denial                                               2
# Lloyd's Cat Code                                     4
# Total days from policy taken to DOL                154
# Total days from DOL to claim made                   90
# Is DOL in policy period                              2
# dtype: int64

# %%
cols=col_names(df)
cols
# Out:
# Index(['Program Name', 'Is Secondary', 'Main Member Non-Diving',
#        'State/Province', 'City', 'Country', 'Original Currency',
#        'Insured State, Province, Territory, Canton etc.', 'Insured Country',
#        'Location of loss Country', 'Cause of Loss Code', 'Denial',
#        'Lloyd's Cat Code', 'Total days from policy taken to DOL',
#        'Total days from DOL to claim made', 'Is DOL in policy period'],
#       dtype='object')

# %%
# Split df in x, y, x_train, x_test, y_train, y_test
x, y, x_train, x_test, y_train, y_test = train_test(df)

# %%
# Perform gridsearchCV to establish best params and test score 
DT_grid(x_train, x_test, y_train, y_test)
# Out:
#  The best cross validation score for the DT model is: 0.4924
#  The best parameters for the DT model: {'class_weight': {0: 1, 1: 25}, 'criterion': 'gini', 'max_depth': 10}
#  Test score: 0.3824

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
DT_acc, DT_cm, DT_precision, DT_recall, DT_f1score, DT_auc, DT_preds = DT_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                               criterion='gini', max_depth=10, 
                                                                               class_weight={0: 1, 1: 25})
print("Accuracy:\t", "%0.4f" % DT_acc)
print("Precision:\t", "%0.4f" % DT_precision)
print("Recall:\t\t", "%0.4f" % DT_recall)
print("F1 Score:\t", "%0.4f" % DT_f1score)
print("AUC:\t\t", "%0.4f" % DT_auc)
DT_cm
# Out:
# Accuracy:	 0.3913
# Precision:	 0.2549
# Recall:		 0.7647
# F1 Score:	 0.3824
# AUC:		 0.5170
# array([[14, 38],
#        [ 4, 13]], dtype=int64)

# %%
# Create confusion matrix 
con = confusion_matrix(y_test, DT_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="coolwarm", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### Random Forrest

# %%
# Perfomed nested CV on DT model 
RF_nested(x_train, y_train)
winsound.MessageBeep()
# Out:
# Average cross_val score of RF: 0.4560

# %%
# Perform gridsearchCV to establish best params and test score 
RF_grid(x_train, x_test, y_train, y_test)
winsound.MessageBeep()
# Out:
#  The best cross validation score for the RF model is: 0.4944
#  The best parameters for the RF model: {'class_weight': {0: 1, 1: 25}, 'criterion': 'gini', 'max_depth': 10}
#  Test score: 0.2963

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
RF_acc, RF_cm, RF_precision, RF_recall, RF_f1score, RF_auc, RF_preds = RF_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                               criterion='gini', max_depth=10, 
                                                                               class_weight={0: 1, 1: 25})
print("RF Accuracy:\t", "%0.4f" % RF_acc)
print("RF Precision:\t", "%0.4f" % RF_precision)
print("RF Recall:\t", "%0.4f" % RF_recall)
print("RF F1 Score:\t", "%0.4f" % RF_f1score)
print("RF AUC:\t\t", "%0.4f" % RF_auc)
RF_cm
# Out:
# RF Accuracy:	 0.4638
# RF Precision:	 0.2222
# RF Recall:	 0.4706
# RF F1 Score:	 0.3019
# RF AUC:		 0.4661
# array([[24, 28],
#        [ 9,  8]], dtype=int64)

# %%
# Confusion matrix for RF
con = confusion_matrix(y_test, RF_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="Greys", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### SVM

# %%
# Perfomed nested CV on SVM model 
SVM_nested(x_train, y_train)
winsound.MessageBeep()
# Out:
# Average cross_val score of SVM: 0.4754

# %%
# Perform gridsearchCV to establish best params and test score 
SVM_grid(x_train, x_test, y_train, y_test)
winsound.MessageBeep()
# Out:
#  The best cross validation score for the SVM model is: 0.4847
#  The best parameters for the SVM model: {'C': 10, 'class_weight': {0: 1, 1: 100}, 'gamma': 0.01}
#  Test score: 0.3684

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
SVM_acc, SVM_cm, SVM_precision, SVM_recall, SVM_f1score, SVM_auc, SVM_preds = SVM_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                               C = 10, class_weight= {0: 1, 1: 100}, 
                                                                                       gamma= 0.01)
print("SVM Accuracy:\t", "%0.4f" % SVM_acc)
print("SVM Precision:\t", "%0.4f" % SVM_precision)
print("SVM Recall:\t", "%0.4f" % SVM_recall)
print("SVM F1 Score:\t", "%0.4f" % SVM_f1score)
print("SVM AUC:\t", "%0.4f" % SVM_auc)
SVM_cm
# Out:
# SVM Accuracy:	 0.3043
# SVM Precision:	 0.2373
# SVM Recall:	 0.8235
# SVM F1 Score:	 0.3684
# SVM AUC:	 0.4791
# array([[ 7, 45],
#        [ 3, 14]], dtype=int64)

# %%
# Confusion matrix for SVM
con = confusion_matrix(y_test, SVM_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="Blues", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### XGBoost

# %%
# Perform nested CV on XGB model 
XGB_nested(x_train, y_train)
winsound.MessageBeep()
# Out:
# Average cross_val score of XGBoost: 0.9250

# %%
# Perform gridsearchCV to establish best params and test score 
XGB_grid(x_train, x_test, y_train, y_test)
winsound.MessageBeep()
# Out:
#  The best cross validation score with parameter tuning for the XGB model is: 0.9625
#  The best parameters for the XGB model: {'learning_rate': 0.01, 'max_depth': 2, 'scale_pos_weight': 10}
#  Test score: 0.9412

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
XGB_acc, XGB_cm, XGB_precision, XGB_recall, XGB_f1score, XGB_auc, XGB_preds = XGB_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                              learning_rate = 0.01, max_depth=2,
                                                                                      scale_pos_weight=10)
print("XGB Accuracy:\t", "%0.4f" % XGB_acc)
print("XGB Precision:\t", "%0.4f" % XGB_precision)
print("XGB Recall:\t", "%0.4f" % XGB_recall)
print("XGB F1 Score:\t", "%0.4f" % XGB_f1score)
print("XGB AUC:\t", "%0.4f" % XGB_auc)
XGB_cm
# Out:
# XGB Accuracy:	 0.2754
# XGB Precision:	 0.2462
# XGB Recall:	 0.9412
# XGB F1 Score:	 0.3902
# XGB AUC:	 0.4994
# array([[ 3, 49],
#        [ 1, 16]], dtype=int64)

# %%
# Confusion matrix for XGB
con = confusion_matrix(y_test, XGB_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="mako_r", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
df.shape
# Out:
# (343, 16)

# %%
df['Denial'].sum()
# Out:
# 97

# %%
## change values for other data set in work, run with get dummies and analyise for improvement

# %%
# Create table of accuracies for data with preprocessing AND binned values  
performance_preprossed_only = pd.DataFrame({
    'Model' : ['Descision Tree', 'Random Forest', 'SVM', 'XGBoost'],
    'Accuracy' : [round(DT_acc, 4), round(RF_acc, 4), round(SVM_acc, 4), round(XGB_acc, 4)],
    'Precision' : [round(DT_precision, 4), round(RF_precision, 4), round(SVM_precision, 4), round(XGB_precision, 4)],
    'Recall' : [round(DT_recall, 4), round(RF_recall, 4), round(SVM_recall, 4), round(XGB_recall, 4)],
    'F1 Score' : [round(DT_f1score, 4), round(RF_f1score, 4), round(SVM_f1score, 4), round(XGB_f1score, 4)],
    'AUC' : [round(DT_auc, 4), round(RF_auc, 4), round(SVM_auc, 4), round(XGB_auc, 4)]
})
performance_preprossed_only_df = performance_preprossed_only.sort_values(by='Recall', ascending=False)
# Model_comparison_df = Model_comparison_df.set_index('Accuracy Score (%)')
# Model_comparison_df.reset_index()

#create table of results
fig =  ff.create_table(performance_preprossed_only_df)
fig.update_layout(
    autosize=False,
    width=700,
    height=200,
)
fig.show()
# Out:
# <div>                            <div id="1d7f4511-1907-42e1-be1e-92c0e3b57e42" class="plotly-graph-div" style="height:200px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d7f4511-1907-42e1-be1e-92c0e3b57e42")) {                    Plotly.newPlot(                        "1d7f4511-1907-42e1-be1e-92c0e3b57e42",                        [{"colorscale":[[0,"#00083e"],[0.5,"#ededee"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"type":"heatmap","z":[[0,0,0,0,0,0],[0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1],[0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1]]}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Model</b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Accuracy</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Precision</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Recall</b>","x":2.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>F1 Score</b>","x":3.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>AUC</b>","x":4.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"XGBoost","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2754","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2462","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.9412","x":2.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3902","x":3.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4994","x":4.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"SVM","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3043","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2373","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.8235","x":2.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3684","x":3.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4791","x":4.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"Descision Tree","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3913","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2549","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.7647","x":2.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3824","x":3.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.517","x":4.55,"xanchor":"left","xre ...

# %% [markdown]
# ### Model with Data Dummies Few

# %% [markdown]
# ### DT

# %%
df_few = import_data().pipe(drop_low_info_cols).pipe(drop_features).pipe(encode).pipe(use_dates).pipe(get_dummies_few)

# %%
# Split df in x, y, x_train, x_test, y_train, y_test
x, y, x_train, x_test, y_train, y_test = train_test(df_few)

# %%
# Perform gridsearchCV to establish best params and test score 
DT_grid(x_train, x_test, y_train, y_test)
# Out:
#  The best cross validation score for the DT model is: 0.4866
#  The best parameters for the DT model: {'class_weight': {0: 1, 1: 25}, 'criterion': 'gini', 'max_depth': 10}
#  Test score: 0.3881

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
DT_acc, DT_cm, DT_precision, DT_recall, DT_f1score, DT_auc, DT_preds = DT_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                               criterion='gini', max_depth=10, 
                                                                               class_weight={0: 1, 1: 25})
print("Accuracy:\t", "%0.4f" % DT_acc)
print("Precision:\t", "%0.4f" % DT_precision)
print("Recall:\t\t", "%0.4f" % DT_recall)
print("F1 Score:\t", "%0.4f" % DT_f1score)
print("AUC:\t\t", "%0.4f" % DT_auc)
DT_cm
# Out:
# Accuracy:	 0.4058
# Precision:	 0.2600
# Recall:		 0.7647
# F1 Score:	 0.3881
# AUC:		 0.5266
# array([[15, 37],
#        [ 4, 13]], dtype=int64)

# %%
# Create confusion matrix 
con = confusion_matrix(y_test, DT_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="coolwarm", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### RF

# %%
# Perfomed nested CV on DT model 
RF_nested(x_train, y_train)
winsound.MessageBeep()
# Out:
# Average cross_val score of RF: 0.4140

# %%
# Perform gridsearchCV to establish best params and test score 
RF_grid(x_train, x_test, y_train, y_test)
winsound.MessageBeep()
# Out:
#  The best cross validation score for the RF model is: 0.4793
#  The best parameters for the RF model: {'class_weight': {0: 1, 1: 10}, 'criterion': 'entropy', 'max_depth': 6}
#  Test score: 0.3582

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
RF_acc, RF_cm, RF_precision, RF_recall, RF_f1score, RF_auc, RF_preds = RF_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                               criterion='entropy', max_depth=6, 
                                                                               class_weight={0: 1, 1: 10})
print("RF Accuracy:\t", "%0.4f" % RF_acc)
print("RF Precision:\t", "%0.4f" % RF_precision)
print("RF Recall:\t", "%0.4f" % RF_recall)
print("RF F1 Score:\t", "%0.4f" % RF_f1score)
print("RF AUC:\t\t", "%0.4f" % RF_auc)
RF_cm
# Out:
# RF Accuracy:	 0.3913
# RF Precision:	 0.2340
# RF Recall:	 0.6471
# RF F1 Score:	 0.3438
# RF AUC:		 0.4774
# array([[16, 36],
#        [ 6, 11]], dtype=int64)

# %%
# Confusion matrix for RF
con = confusion_matrix(y_test, RF_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="Greys", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### SVM

# %%
# Perfomed nested CV on SVM model 
SVM_nested(x_train, y_train)
winsound.MessageBeep()
# Out:
# Average cross_val score of SVM: 0.4773

# %%
# Perform gridsearchCV to establish best params and test score 
SVM_grid(x_train, x_test, y_train, y_test)
winsound.MessageBeep()
# Out:
#  The best cross validation score for the SVM model is: 0.4788
#  The best parameters for the SVM model: {'C': 250, 'class_weight': {0: 1, 1: 100}, 'gamma': 0.001}
#  Test score: 0.3944

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
SVM_acc, SVM_cm, SVM_precision, SVM_recall, SVM_f1score, SVM_auc, SVM_preds = SVM_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                               C = 250, class_weight= {0: 1, 1: 100}, 
                                                                                       gamma= 0.001)
print("SVM Accuracy:\t", "%0.4f" % SVM_acc)
print("SVM Precision:\t", "%0.4f" % SVM_precision)
print("SVM Recall:\t", "%0.4f" % SVM_recall)
print("SVM F1 Score:\t", "%0.4f" % SVM_f1score)
print("SVM AUC:\t", "%0.4f" % SVM_auc)
SVM_cm
# Out:
# SVM Accuracy:	 0.3768
# SVM Precision:	 0.2593
# SVM Recall:	 0.8235
# SVM F1 Score:	 0.3944
# SVM AUC:	 0.5271
# array([[12, 40],
#        [ 3, 14]], dtype=int64)

# %%
# Confusion matrix for SVM
con = confusion_matrix(y_test, SVM_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="Blues", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### XGBoost

# %%
# Perform nested CV on XGB model 
XGB_nested(x_train, y_train)
winsound.MessageBeep()
# Out:
# Average cross_val score of XGBoost: 0.9250

# %%
# Perform gridsearchCV to establish best params and test score 
XGB_grid(x_train, x_test, y_train, y_test)
winsound.MessageBeep()
# Out:
#  The best cross validation score with parameter tuning for the XGB model is: 0.9625
#  The best parameters for the XGB model: {'learning_rate': 0.01, 'max_depth': 2, 'scale_pos_weight': 10}
#  Test score: 0.9412

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
XGB_acc, XGB_cm, XGB_precision, XGB_recall, XGB_f1score, XGB_auc, XGB_preds = XGB_eval(x_train, 
                                                                              x_test, y_train, y_test, 
                                                                              learning_rate = 0.01, max_depth=2,
                                                                              scale_pos_weight=10)
print("XGB Accuracy:\t", "%0.4f" % XGB_acc)
print("XGB Precision:\t", "%0.4f" % XGB_precision)
print("XGB Recall:\t", "%0.4f" % XGB_recall)
print("XGB F1 Score:\t", "%0.4f" % XGB_f1score)
print("XGB AUC:\t", "%0.4f" % XGB_auc)
XGB_cm
# Out:
# XGB Accuracy:	 0.2754
# XGB Precision:	 0.2462
# XGB Recall:	 0.9412
# XGB F1 Score:	 0.3902
# XGB AUC:	 0.4994
# array([[ 3, 49],
#        [ 1, 16]], dtype=int64)

# %%
# Confusion matrix for XGB
con = confusion_matrix(y_test, XGB_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="mako_r", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Create table of accuracies for data with preprocessing AND binned values  
performance_preprossed_only = pd.DataFrame({
    'Model' : ['Descision Tree', 'Random Forest', 'SVM', 'XGBoost'],
    'Accuracy' : [round(DT_acc, 4), round(RF_acc, 4), round(SVM_acc, 4), round(XGB_acc, 4)],
    'Precision' : [round(DT_precision, 4), round(RF_precision, 4), round(SVM_precision, 4), round(XGB_precision, 4)],
    'Recall' : [round(DT_recall, 4), round(RF_recall, 4), round(SVM_recall, 4), round(XGB_recall, 4)],
    'F1 Score' : [round(DT_f1score, 4), round(RF_f1score, 4), round(SVM_f1score, 4), round(XGB_f1score, 4)],
    'AUC' : [round(DT_auc, 4), round(RF_auc, 4), round(SVM_auc, 4), round(XGB_auc, 4)]
})
performance_preprossed_only_df = performance_preprossed_only.sort_values(by='Recall', ascending=False)
# Model_comparison_df = Model_comparison_df.set_index('Accuracy Score (%)')
# Model_comparison_df.reset_index()

#create table of results
fig =  ff.create_table(performance_preprossed_only_df)
fig.update_layout(
    autosize=False,
    width=700,
    height=200,
)
fig.show()
# Out:
# <div>                            <div id="de3f7881-5a7a-40a3-a0d2-f0d167da8eaf" class="plotly-graph-div" style="height:200px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de3f7881-5a7a-40a3-a0d2-f0d167da8eaf")) {                    Plotly.newPlot(                        "de3f7881-5a7a-40a3-a0d2-f0d167da8eaf",                        [{"colorscale":[[0,"#00083e"],[0.5,"#ededee"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"type":"heatmap","z":[[0,0,0,0,0,0],[0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1],[0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1]]}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Model</b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Accuracy</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Precision</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Recall</b>","x":2.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>F1 Score</b>","x":3.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>AUC</b>","x":4.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"XGBoost","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2754","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2462","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.9412","x":2.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3902","x":3.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4994","x":4.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"SVM","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3768","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2593","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.8235","x":2.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3944","x":3.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.5271","x":4.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"Descision Tree","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4058","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.26","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.7647","x":2.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3881","x":3.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.5266","x":4.55,"xanchor":"left","xref ...

# %% [markdown]
# ## Data Preprocessed and Dummies All

# %% [markdown]
# ## DT

# %%
df_all = import_data().pipe(drop_low_info_cols).pipe(drop_features).pipe(encode).pipe(use_dates).pipe(get_dummies_all)

# %%
# Split df in x, y, x_train, x_test, y_train, y_test
x, y, x_train, x_test, y_train, y_test = train_test(df_all)

# %%
# Perform gridsearchCV to establish best params and test score 
DT_grid(x_train, x_test, y_train, y_test)
# Out:
#  The best cross validation score for the DT model is: 0.4655
#  The best parameters for the DT model: {'class_weight': {0: 1, 1: 25}, 'criterion': 'entropy', 'max_depth': 6}
#  Test score: 0.3733

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
DT_acc, DT_cm, DT_precision, DT_recall, DT_f1score, DT_auc, DT_preds = DT_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                               criterion='entropy', max_depth=6, 
                                                                               class_weight={0: 1, 1: 25})
print("Accuracy:\t", "%0.4f" % DT_acc)
print("Precision:\t", "%0.4f" % DT_precision)
print("Recall:\t\t", "%0.4f" % DT_recall)
print("F1 Score:\t", "%0.4f" % DT_f1score)
print("AUC:\t\t", "%0.4f" % DT_auc)
DT_cm
# Out:
# Accuracy:	 0.3188
# Precision:	 0.2414
# Recall:		 0.8235
# F1 Score:	 0.3733
# AUC:		 0.4887
# array([[ 8, 44],
#        [ 3, 14]], dtype=int64)

# %%
# Create confusion matrix 
con = confusion_matrix(y_test, DT_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="coolwarm", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### RF

# %%
# Perfomed nested CV on RF model 
RF_nested(x_train, y_train)
winsound.MessageBeep()
# Out:
# Average cross_val score of RF: 0.4084

# %%
# Perform gridsearchCV to establish best params and test score 
RF_grid(x_train, x_test, y_train, y_test)
winsound.MessageBeep()
# Out:
#  The best cross validation score for the RF model is: 0.4591
#  The best parameters for the RF model: {'class_weight': {0: 1, 1: 5}, 'criterion': 'entropy', 'max_depth': 8}
#  Test score: 0.4267

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
RF_acc, RF_cm, RF_precision, RF_recall, RF_f1score, RF_auc, RF_preds = RF_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                               criterion='entropy', max_depth=8, 
                                                                               class_weight={0: 1, 1: 5})
print("RF Accuracy:\t", "%0.4f" % RF_acc)
print("RF Precision:\t", "%0.4f" % RF_precision)
print("RF Recall:\t", "%0.4f" % RF_recall)
print("RF F1 Score:\t", "%0.4f" % RF_f1score)
print("RF AUC:\t\t", "%0.4f" % RF_auc)
RF_cm
# Out:
# RF Accuracy:	 0.3623
# RF Precision:	 0.2712
# RF Recall:	 0.9412
# RF F1 Score:	 0.4211
# RF AUC:		 0.5571
# array([[ 9, 43],
#        [ 1, 16]], dtype=int64)

# %%
# Confusion matrix for RF
con = confusion_matrix(y_test, RF_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="Greys", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### SVM

# %%
# Perfomed nested CV on SVM model 
SVM_nested(x_train, y_train)
winsound.MessageBeep()
# Out:
# Average cross_val score of SVM: 0.4521

# %%
# Perform gridsearchCV to establish best params and test score 
SVM_grid(x_train, x_test, y_train, y_test)
winsound.MessageBeep()
# Out:
#  The best cross validation score for the SVM model is: 0.4520
#  The best parameters for the SVM model: {'C': 0.1, 'class_weight': {0: 1, 1: 10}, 'gamma': 1}
#  Test score: 0.3953

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
SVM_acc, SVM_cm, SVM_precision, SVM_recall, SVM_f1score, SVM_auc, SVM_preds = SVM_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                               C = 0.1, class_weight= {0: 1, 1: 10}, 
                                                                                       gamma= 1)
print("SVM Accuracy:\t", "%0.4f" % SVM_acc)
print("SVM Precision:\t", "%0.4f" % SVM_precision)
print("SVM Recall:\t", "%0.4f" % SVM_recall)
print("SVM F1 Score:\t", "%0.4f" % SVM_f1score)
print("SVM AUC:\t", "%0.4f" % SVM_auc)
SVM_cm
# Out:
# SVM Accuracy:	 0.2464
# SVM Precision:	 0.2464
# SVM Recall:	 1.0000
# SVM F1 Score:	 0.3953
# SVM AUC:	 0.5000
# array([[ 0, 52],
#        [ 0, 17]], dtype=int64)

# %%
# Confusion matrix for SVM
con = confusion_matrix(y_test, SVM_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="Blues", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### XGBoost

# %%
# Perform nested CV on XGB model 
XGB_nested(x_train, y_train)
winsound.MessageBeep()
# Out:
# Average cross_val score of XGBoost: 0.9625

# %%
# Perform gridsearchCV to establish best params and test score 
XGB_grid(x_train, x_test, y_train, y_test)
winsound.MessageBeep()
# Out:
#  The best cross validation score with parameter tuning for the XGB model is: 0.9875
#  The best parameters for the XGB model: {'learning_rate': 0.0001, 'max_depth': 2, 'scale_pos_weight': 50}
#  Test score: 0.8824

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
XGB_acc, XGB_cm, XGB_precision, XGB_recall, XGB_f1score, XGB_auc, XGB_preds = XGB_eval(x_train, 
                                                                              x_test, y_train, y_test, 
                                                                              learning_rate = 0.0001, max_depth=2,
                                                                              scale_pos_weight=50)
print("XGB Accuracy:\t", "%0.4f" % XGB_acc)
print("XGB Precision:\t", "%0.4f" % XGB_precision)
print("XGB Recall:\t", "%0.4f" % XGB_recall)
print("XGB F1 Score:\t", "%0.4f" % XGB_f1score)
print("XGB AUC:\t", "%0.4f" % XGB_auc)
XGB_cm
# Out:
# XGB Accuracy:	 0.2754
# XGB Precision:	 0.2381
# XGB Recall:	 0.8824
# XGB F1 Score:	 0.3750
# XGB AUC:	 0.4796
# array([[ 4, 48],
#        [ 2, 15]], dtype=int64)

# %%
# Confusion matrix for XGB
con = confusion_matrix(y_test, XGB_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="mako_r", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Create table of accuracies for data with preprocessing AND binned values  
performance_preprossed_only = pd.DataFrame({
    'Model' : ['Descision Tree', 'Random Forest', 'SVM', 'XGBoost'],
    'Accuracy' : [round(DT_acc, 4), round(RF_acc, 4), round(SVM_acc, 4), round(XGB_acc, 4)],
    'Precision' : [round(DT_precision, 4), round(RF_precision, 4), round(SVM_precision, 4), round(XGB_precision, 4)],
    'Recall' : [round(DT_recall, 4), round(RF_recall, 4), round(SVM_recall, 4), round(XGB_recall, 4)],
    'F1 Score' : [round(DT_f1score, 4), round(RF_f1score, 4), round(SVM_f1score, 4), round(XGB_f1score, 4)],
    'AUC' : [round(DT_auc, 4), round(RF_auc, 4), round(SVM_auc, 4), round(XGB_auc, 4)]
})
performance_preprossed_only_df = performance_preprossed_only.sort_values(by='Recall', ascending=False)
# Model_comparison_df = Model_comparison_df.set_index('Accuracy Score (%)')
# Model_comparison_df.reset_index()

#create table of results
fig =  ff.create_table(performance_preprossed_only_df)
fig.update_layout(
    autosize=False,
    width=700,
    height=200,
)
fig.show()
# Out:
# <div>                            <div id="f285f1ca-c17f-4978-ba0e-51a0b0d78a8a" class="plotly-graph-div" style="height:200px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f285f1ca-c17f-4978-ba0e-51a0b0d78a8a")) {                    Plotly.newPlot(                        "f285f1ca-c17f-4978-ba0e-51a0b0d78a8a",                        [{"colorscale":[[0,"#00083e"],[0.5,"#ededee"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"type":"heatmap","z":[[0,0,0,0,0,0],[0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1],[0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1]]}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Model</b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Accuracy</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Precision</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Recall</b>","x":2.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>F1 Score</b>","x":3.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>AUC</b>","x":4.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"SVM","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2464","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2464","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":2.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3953","x":3.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.5","x":4.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"Random Forest","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3623","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2712","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.9412","x":2.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4211","x":3.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.5571","x":4.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"XGBoost","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2754","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2381","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.8824","x":2.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.375","x":3.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4796","x":4.55,"xanchor":"left","xref":"x", ...

# %% [markdown]
# ###  Data Preprocessed + SMOTE

# %% [markdown]
# ### DT

# %%
df_s = import_data().pipe(drop_low_info_cols).pipe(drop_features).pipe(encode).pipe(use_dates)

# %%
# Split df in x, y, x_train, x_test, y_train, y_test
x, y, x_train, x_test, y_train, y_test = train_test(df_s)

# %%
x_train, y_train = sm.fit_resample(x_train, y_train)

# %%
# Perform gridsearchCV to establish best params and test score 
DT_grid(x_train, x_test, y_train, y_test)
# Out:
#  The best cross validation score for the DT model is: 0.7442
#  The best parameters for the DT model: {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 10}
#  Test score: 0.3500

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
DT_acc, DT_cm, DT_precision, DT_recall, DT_f1score, DT_auc, DT_preds = DT_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                               criterion='gini', max_depth=10, 
                                                                               class_weight='balanced')
print("Accuracy:\t", "%0.4f" % DT_acc)
print("Precision:\t", "%0.4f" % DT_precision)
print("Recall:\t\t", "%0.4f" % DT_recall)
print("F1 Score:\t", "%0.4f" % DT_f1score)
print("AUC:\t\t", "%0.4f" % DT_auc)
DT_cm
# Out:
# Accuracy:	 0.6522
# Precision:	 0.3478
# Recall:		 0.4706
# F1 Score:	 0.4000
# AUC:		 0.5911
# array([[37, 15],
#        [ 9,  8]], dtype=int64)

# %%
# Create confusion matrix 
con = confusion_matrix(y_test, DT_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="coolwarm", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### RF

# %%
# Perfomed nested CV on RF model 
RF_nested(x_train, y_train)
winsound.MessageBeep()
# Out:
# Average cross_val score of RF: 0.7295

# %%
# Perform gridsearchCV to establish best params and test score 
RF_grid(x_train, x_test, y_train, y_test)
winsound.MessageBeep()
# Out:
#  The best cross validation score for the RF model is: 0.7600
#  The best parameters for the RF model: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 10}
#  Test score: 0.4242

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
RF_acc, RF_cm, RF_precision, RF_recall, RF_f1score, RF_auc, RF_preds = RF_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                               criterion='gini', max_depth=10, 
                                                                               class_weight='balanced')
print("RF Accuracy:\t", "%0.4f" % RF_acc)
print("RF Precision:\t", "%0.4f" % RF_precision)
print("RF Recall:\t", "%0.4f" % RF_recall)
print("RF F1 Score:\t", "%0.4f" % RF_f1score)
print("RF AUC:\t\t", "%0.4f" % RF_auc)
RF_cm
# Out:
# RF Accuracy:	 0.7246
# RF Precision:	 0.4444
# RF Recall:	 0.4706
# RF F1 Score:	 0.4571
# RF AUC:		 0.6391
# array([[42, 10],
#        [ 9,  8]], dtype=int64)

# %%
# Confusion matrix for RF
con = confusion_matrix(y_test, RF_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="Greys", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### SVM

# %%
# Perfomed nested CV on SVM model 
SVM_nested(x_train, y_train)
winsound.MessageBeep()
# Out:
# Average cross_val score of SVM: 0.7429

# %%
# Perform gridsearchCV to establish best params and test score 
SVM_grid(x_train, x_test, y_train, y_test)
winsound.MessageBeep()
# Out:
#  The best cross validation score for the SVM model is: 0.7466
#  The best parameters for the SVM model: {'C': 100, 'class_weight': {0: 100, 1: 1}, 'gamma': 0.1}
#  Test score: 0.3500

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
SVM_acc, SVM_cm, SVM_precision, SVM_recall, SVM_f1score, SVM_auc, SVM_preds = SVM_eval(x_train, 
                                                                               x_test, y_train, y_test, 
                                                                               C = 100, class_weight= {0: 1, 1: 100}, 
                                                                                       gamma= 0.1)
print("SVM Accuracy:\t", "%0.4f" % SVM_acc)
print("SVM Precision:\t", "%0.4f" % SVM_precision)
print("SVM Recall:\t", "%0.4f" % SVM_recall)
print("SVM F1 Score:\t", "%0.4f" % SVM_f1score)
print("SVM AUC:\t", "%0.4f" % SVM_auc)
SVM_cm
# Out:
# SVM Accuracy:	 0.5652
# SVM Precision:	 0.2400
# SVM Recall:	 0.3529
# SVM F1 Score:	 0.2857
# SVM AUC:	 0.4938
# array([[33, 19],
#        [11,  6]], dtype=int64)

# %%
# Confusion matrix for SVM
con = confusion_matrix(y_test, SVM_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="Blues", annot=True, fmt='g', xticklabels=('Predicted No Fraud', 'Predicted Fraud'), 
            yticklabels=('No Fraud', 'Fraud'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### XGBoost

# %%
# Perform nested CV on XGB model 
XGB_nested(x_train, y_train)
winsound.MessageBeep()
# Out:
# Average cross_val score of XGBoost: 0.9692

# %%
## Perform gridsearchCV to establish best params and test score 
XGB_grid(x_train, x_test, y_train, y_test)
winsound.MessageBeep()
# Out:
#  The best cross validation score with parameter tuning for the XGB model is: 0.9897
#  The best parameters for the XGB model: {'learning_rate': 0.01, 'max_depth': 2, 'scale_pos_weight': 10}
#  Test score: 1.0000

# %%
# Call the eval function manually inputting best aparams for clf and print evaluation results 
XGB_acc, XGB_cm, XGB_precision, XGB_recall, XGB_f1score, XGB_auc, XGB_preds = XGB_eval(x_train, 
                                                                              x_test, y_train, y_test, 
                                                                              learning_rate = 0.01, max_depth=2,
                                                                              scale_pos_weight=10)
print("XGB Accuracy:\t", "%0.4f" % XGB_acc)
print("XGB Precision:\t", "%0.4f" % XGB_precision)
print("XGB Recall:\t", "%0.4f" % XGB_recall)
print("XGB F1 Score:\t", "%0.4f" % XGB_f1score)
print("XGB AUC:\t", "%0.4f" % XGB_auc)
XGB_cm
# Out:
# XGB Accuracy:	 0.2609
# XGB Precision:	 0.2500
# XGB Recall:	 1.0000
# XGB F1 Score:	 0.4000
# XGB AUC:	 0.5096
# array([[ 1, 51],
#        [ 0, 17]], dtype=int64)

# %%
# Confusion matrix for XGB
con = confusion_matrix(y_test, XGB_preds)
con
plt.figure(figsize=(8,6))
sns.heatmap(con, cmap="mako_r", annot=True, fmt='g', xticklabels=('Predicted Low Risk', 'Predicted High Risk'), 
            yticklabels=('Low Risk', 'High Risk'))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Create table of accuracies for data with preprocessing AND binned values  
performance_preprossed_only = pd.DataFrame({
    'Model' : ['Descision Tree', 'Random Forest', 'SVM', 'XGBoost'],
    'Accuracy' : [round(DT_acc, 4), round(RF_acc, 4), round(SVM_acc, 4), round(XGB_acc, 4)],
    'Precision' : [round(DT_precision, 4), round(RF_precision, 4), round(SVM_precision, 4), round(XGB_precision, 4)],
    'Recall' : [round(DT_recall, 4), round(RF_recall, 4), round(SVM_recall, 4), round(XGB_recall, 4)],
    'F1 Score' : [round(DT_f1score, 4), round(RF_f1score, 4), round(SVM_f1score, 4), round(XGB_f1score, 4)],
    'AUC' : [round(DT_auc, 4), round(RF_auc, 4), round(SVM_auc, 4), round(XGB_auc, 4)]
})
performance_preprossed_only_df = performance_preprossed_only.sort_values(by='Recall', ascending=False)
# Model_comparison_df = Model_comparison_df.set_index('Accuracy Score (%)')
# Model_comparison_df.reset_index()

#create table of results
fig =  ff.create_table(performance_preprossed_only_df)
fig.update_layout(
    autosize=False,
    width=700,
    height=200,
)
fig.show()
# Out:
# <div>                            <div id="54527596-3abf-4ded-afa2-2bdda5db908d" class="plotly-graph-div" style="height:200px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54527596-3abf-4ded-afa2-2bdda5db908d")) {                    Plotly.newPlot(                        "54527596-3abf-4ded-afa2-2bdda5db908d",                        [{"colorscale":[[0,"#00083e"],[0.5,"#ededee"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"type":"heatmap","z":[[0,0,0,0,0,0],[0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1],[0.5,0.5,0.5,0.5,0.5,0.5],[1,1,1,1,1,1]]}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Model</b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Accuracy</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Precision</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Recall</b>","x":2.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>F1 Score</b>","x":3.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>AUC</b>","x":4.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"XGBoost","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2609","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.25","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":2.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4","x":3.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.5096","x":4.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"Descision Tree","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.6522","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3478","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4706","x":2.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4","x":3.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.5911","x":4.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"Random Forest","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.7246","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4444","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4706","x":2.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4571","x":3.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.6391","x":4.55,"xanchor":"left","xre ...

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# ### XGBoost

# %%
clf_XGB = XGBClassifier(validate_parameters=True, objective="binary:logistic", silent=True, verbosity=0,
                       learning_rate = 0.01, max_depth = 2, scale_pos_weight = 10)
clf_XGB.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.01, max_delta_step=0, max_depth=2,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=10, silent=True,
#               subsample=1, tree_method='exact', validate_parameters=True,
#               verbosity=0)

# %%
feature_importance(clf_XGB)
